# %%
distribution of the data
how to check normality of the data
z test
t test
chi squre
anova test(f test)

# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns

# %%
sns.distplot(data_copy)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy.sort()

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(289)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 289]

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy2=data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2[0]=-10

# %%
data_copy2
# Out:
# [-10, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-50)

# %%
data_copy2
# Out:
# [-50, -10, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-175)

# %%
data_copy2
# Out:
# [-175, -50, -10, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(3,23)

# %%
data_copy2
# Out:
# [-175, -50, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.histplot(df["SepalLengthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(df["SepalWidthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(df["PetalLengthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(df["PetalWidthCm"],kde=True)
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Count'>

# %%
import numpy as np
s=np.random.normal(0.5,0.2,1000)

# %%
s
# Out:
# array([ 0.4352933 ,  0.63545065,  0.230842  ,  0.214589  ,  0.2324807 ,
#         0.72696496,  0.49667889,  0.69552759,  0.59456973,  0.48074963,
#         0.60707907,  0.46957799,  0.63417516,  0.78236761,  0.34689831,
#         0.48098815,  0.69869996,  0.37975228,  0.44827095,  0.22326364,
#         0.32413788,  0.27364033,  0.48124249,  0.52481789,  0.65875514,
#         0.36337898,  0.14565763,  0.80649601,  0.48447527,  0.68914874,
#         0.44924944,  0.76988102,  0.255713  ,  0.64545768,  0.58055748,
#         0.28941477,  0.4199919 ,  0.00398354,  0.51756339,  0.32286356,
#         0.44343803,  0.35252701,  0.67579998,  0.63086949,  0.85384471,
#         0.97264536,  0.95666439,  0.70960124,  0.65896207,  0.31703007,
#         0.35664803,  0.40597857,  0.8449779 ,  0.31674219,  0.44172462,
#         0.67167691,  0.81064462,  0.46953562,  0.37477297,  0.69250035,
#         0.24978918,  0.76062823,  0.60945493,  0.66785818,  0.38024195,
# ...

# %%
sns.histplot(s,kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
np.random.lognormal(0.3,0.1,1000)
# Out:
# array([1.36268883, 1.51545059, 1.4865412 , 1.53622624, 1.36021448,
#        1.51135611, 1.36370914, 1.15585956, 1.55115413, 1.38465807,
#        1.314794  , 1.41069251, 1.4447172 , 1.46703832, 1.54032718,
#        1.78447632, 1.21355271, 1.26570369, 1.35084753, 1.28866577,
#        1.07742654, 1.41776514, 1.33155696, 1.32845359, 1.44899415,
#        1.44986293, 1.27355373, 1.24315061, 1.24164589, 1.44105051,
#        1.38576836, 1.28603676, 1.25554724, 1.11504158, 1.4553385 ,
#        1.27198031, 1.44552289, 1.50368071, 1.57423693, 1.11133553,
#        1.6222669 , 1.15524947, 1.25079451, 1.04798063, 1.50776042,
#        1.31738133, 1.14775793, 1.39723633, 1.59317641, 1.29949218,
#        1.22996053, 1.35342366, 1.58103307, 1.54088896, 1.32979021,
#        1.21555781, 1.36994656, 1.39317654, 1.55962209, 1.38384721,
#        1.21054235, 1.3529941 , 1.41699971, 1.27730485, 1.52451938,
#        1.47434196, 1.10582696, 1.10372075, 1.40235816, 1.42407587,
# ...

# %%
sns.histplot(np.random.lognormal(0.3,0.1,1000))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mu,sigma=3.0,1.0
p=np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(p)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(p)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(p)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(np.log(p))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(np.log(p))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
p
# Out:
# array([7.16967953e+01, 2.34154711e+01, 1.46100893e+01, 6.30854326e+01,
#        2.48770671e+01, 1.04269341e+01, 4.28401447e+01, 3.39580882e+01,
#        2.83221540e+01, 2.83079631e+01, 4.34371476e+00, 1.11967905e+01,
#        8.44681934e+00, 1.01258635e+01, 1.37886722e+01, 1.77741857e+01,
#        1.16767537e+01, 1.91105439e+01, 4.88635906e+01, 1.07486802e+02,
#        9.87326683e+00, 8.73768092e+00, 5.87171831e+01, 4.87086413e+00,
#        1.26880348e+01, 5.21548380e+01, 8.10506097e+01, 3.40654925e+01,
#        1.08962440e+01, 2.44483447e+01, 6.48580313e+00, 5.47227934e+01,
#        1.52017673e+00, 1.34123348e+01, 5.29864052e+01, 1.32712024e+02,
#        7.11956493e+00, 3.99634496e+01, 4.75928990e+01, 3.51529488e+01,
#        4.80554762e+00, 1.54773911e+01, 2.70556298e+02, 1.26049955e+01,
#        3.44080680e+01, 5.80379109e+00, 8.18484025e+00, 1.15514302e+01,
#        1.70428380e+02, 2.17410701e+02, 1.19344593e+02, 4.17664223e+01,
# ...

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

# %%
def plot_data(sample):
    plt.figure(figsize=(10,8))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist="norm",plot=pylab)
    plt.show()

# %%
plot_data(np.log(p))

# %%
plot_data(p)

# %%
plot_data(df["PetalLengthCm"])

# %%
sns.histplot(np.exp(np.log(p)),kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
d=np.random.randint(10,50,1000)

# %%
sns.distplot(np.exp(d))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip list
# Out:
# Package                            Version              Location
# ---------------------------------- -------------------- ------------------------------------------------------------------------
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
s
# Out:
# array([ 0.4352933 ,  0.63545065,  0.230842  ,  0.214589  ,  0.2324807 ,
#         0.72696496,  0.49667889,  0.69552759,  0.59456973,  0.48074963,
#         0.60707907,  0.46957799,  0.63417516,  0.78236761,  0.34689831,
#         0.48098815,  0.69869996,  0.37975228,  0.44827095,  0.22326364,
#         0.32413788,  0.27364033,  0.48124249,  0.52481789,  0.65875514,
#         0.36337898,  0.14565763,  0.80649601,  0.48447527,  0.68914874,
#         0.44924944,  0.76988102,  0.255713  ,  0.64545768,  0.58055748,
#         0.28941477,  0.4199919 ,  0.00398354,  0.51756339,  0.32286356,
#         0.44343803,  0.35252701,  0.67579998,  0.63086949,  0.85384471,
#         0.97264536,  0.95666439,  0.70960124,  0.65896207,  0.31703007,
#         0.35664803,  0.40597857,  0.8449779 ,  0.31674219,  0.44172462,
#         0.67167691,  0.81064462,  0.46953562,  0.37477297,  0.69250035,
#         0.24978918,  0.76062823,  0.60945493,  0.66785818,  0.38024195,
# ...

# %%
sns.distplot(df["SepalWidthCm"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %% [markdown]
# # Shapiro–Wilk test

# %%
from scipy import stats
stats.shapiro(df["SepalWidthCm"])
# Out:
# ShapiroResult(statistic=0.9837920665740967, pvalue=0.07518772780895233)

# %%
null_hyphothesis=my data is a normally dist

# %%
pvalue=0.07518772780895233

# %%
if pvalue<0.05:
    print("reject the null hyphothesis")
else:
    print("accpet the null pythothesis")
# Out:
# accpet the null pythothesis

# %%
sns.histplot(p)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
stats.shapiro(p)
# Out:
# ShapiroResult(statistic=0.48884350061416626, pvalue=0.0)

# %% [markdown]
# # null_hyphothesis=my data is a normally dist

# %%
pvalue=0.0
if pvalue<0.05:
    print("reject the null hyphothesis")
else:
    print("accpet the null pythothesis")
# Out:
# reject the null hyphothesis

# %%
sns.histplot(np.log(p))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
stats.shapiro(np.log(p))
# Out:
# ShapiroResult(statistic=0.9979913830757141, pvalue=0.2790399193763733)

# %% [markdown]
# ### Null_Hyphothes_is=my data is a normally dist

# %%
pvalue=0.2790399193763733
if pvalue<0.05:
    print("reject the null hyphothesis")
else:
    print("accpet the null pythothesis")
# Out:
# accpet the null pythothesis

# %% [markdown]
# # null hypothesis that a sample comes from a normal distribution.

# %%
from scipy import stats
stats.normaltest(np.log(p))
# Out:
# NormaltestResult(statistic=2.704465349811789, pvalue=0.25866210707600024)

# %%
from scipy import stats
stats.anderson(np.log(p))
# Out:
# AndersonResult(statistic=0.797360342492766, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %% [markdown]
# z- test
# t-test
# chi-squre
# anova test

# %% [markdown]
# # Z- test

# %%
import math
import numpy as np
from numpy.random import randn
from statsmodels.stats.weightstats import ztest

# %%
mean_iq = 110
sd_id  = 15/math.sqrt(50)
alpha = 0.05

# %%
null_hyphothesis_mean=100

# %%
data=randn(50)+mean_iq

# %%
data
# Out:
# array([110.09499617, 108.43658067, 109.81173551, 110.20966904,
#        111.16706873, 109.84191046, 110.54790875, 109.62311707,
#        111.57304049, 111.64985755, 111.06835186, 109.4013593 ,
#        110.750062  , 107.96779828, 108.95703038, 110.7097806 ,
#        110.90527438, 110.66595032, 110.53631373, 108.87977573,
#        110.51387339, 109.22483434, 110.53426233, 108.56494374,
#        109.38712677, 110.36178512, 109.19367767, 109.70932253,
#        110.67226061, 110.52983925, 111.16425588, 110.36063458,
#        111.37407604, 110.91596042, 109.85355587, 108.74925456,
#        109.36300898, 108.64310977, 109.68386296, 108.6878014 ,
#        111.06660145, 111.13299554, 110.63526572, 109.9862878 ,
#        111.06938485, 110.57532554, 109.15090904, 110.42765959,
#        109.62301288, 110.41152589])

# %%
ztest(data,value=null_hyphothesis_mean,alternative='larger')
# Out:
# (78.61927130559452, 0.0)

# %%
### what is my null hyphothesis

the mean should be equal to 100

# %%
p_value= 0.0

if p_value<=0.05:
    print("reject the null hyphothesis")
else:
    print("accpet the null hyphothesis")
# Out:
# reject the null hyphothesis

# %%
mean my population mean or iq wont be equal to 100

# %% [markdown]
# # t-test

# %%
one-sample t test(with respect to one independent sample)
two-sample t test(with respect to two independent sample)
paired t-test(two sample from the same population on different time interval)

# %%
my_total_innings_in_cricket=np.random.randint(10,60,50)

# %%
my_total_innings_in_cricket
# Out:
# array([53, 46, 59, 15, 40, 29, 23, 17, 51, 48, 26, 51, 22, 30, 59, 29, 21,
#        35, 51, 10, 39, 24, 10, 13, 11, 40, 27, 55, 58, 41, 58, 50, 23, 38,
#        17, 11, 16, 54, 28, 13, 38, 49, 49, 36, 32, 29, 13, 53, 16, 20])

# %%
my_cricket_score_in_20_innings=np.random.choice(population,20)

# %%
#my_cricket_score_in_20_innings=[22,38,19,15,48,11,10,49,47,38,10,25,46,10,21,24,29,36,25,24]

# %%
len(my_cricket_score_in_20_innings)
# Out:
# 20

# %%
np.mean(my_cricket_score)
# Out:
# 27.35

# %%
null_hyphothesis=27.35

# %%
from scipy import stats
stats.ttest_1samp(my_cricket_score,50)
# Out:
# Ttest_1sampResult(statistic=-7.540580158527727, pvalue=3.9883518262880924e-07)

# %%
 pvalue=0.4436471890038206

# %%
if pvalue<=0.05:
    print("rejet the null hyphothesis")
else:
    print("accept the null hyphothsis")
# Out:
# accept the null hyphothsis

# %% [markdown]
# # two-sample t test(with respect to two independent sample)

# %%
import numpy as np
my_total_inn_score_in_cricket=np.random.randint(10,50,50)

# %%
virat_total_inn_score_in_cricket=np.random.randint(20,90,50)

# %%
my_total_inn_score_in_cricket
# Out:
# array([14, 18, 24, 33, 39, 31, 15, 26, 46, 45, 31, 31, 24, 33, 11, 37, 45,
#        44, 33, 35, 48, 22, 40, 19, 48, 19, 44, 10, 20, 23, 22, 25, 48, 19,
#        31, 30, 13, 42, 43, 21, 35, 37, 44, 23, 22, 20, 37, 48, 37, 20])

# %%
np.mean(my_total_inn_score_in_cricket)
# Out:
# 30.5

# %%
my20_inning_score=np.random.choice(my_total_inn_score_in_cricket,20)

# %%
my20_inning_score
# Out:
# array([22, 44, 48, 10, 37, 19, 22, 19, 35, 19, 35, 44, 37, 33, 31, 31, 48,
#        40, 30, 10])

# %%
np.mean(my20_inning_score)
# Out:
# 30.7

# %%
virat_total_inn_score_in_cricket
# Out:
# array([21, 77, 56, 88, 65, 40, 39, 75, 84, 27, 21, 55, 76, 56, 75, 38, 86,
#        69, 46, 27, 25, 74, 22, 44, 72, 62, 30, 67, 54, 52, 22, 57, 43, 32,
#        56, 77, 21, 21, 86, 48, 32, 84, 60, 85, 61, 68, 30, 41, 43, 43])

# %%
np.mean(virat_total_inn_score_in_cricket)
# Out:
# 52.66

# %%
virat20_inning_score=np.random.choice(virat_total_inn_score_in_cricket,20)

# %%
np.mean(virat20_inning_score)
# Out:
# 51.7

# %%
#null_hyphothesis=both sample mean are same

# %%
from scipy import stats
stats.ttest_ind(virat20_inning_score,my20_inning_score)
# Out:
# Ttest_indResult(statistic=4.6620039651587435, pvalue=3.793505126672983e-05)

# %%
pvalue=3.793505126672983e-05

if pvalue<=0.05:
    print("you are going to reject the null hyphothesis means both sample mean are not same")
else:
    print("you are going to accept the null hyphothesis means both sample mean are same")
# Out:
# you are going to reject the null hyphothesis means both sample mean are not same

# %% [markdown]
# # paired t-test(two sample from the same population on different time interval)

# %%
my_total_inn_score_in_cricket=np.random.randint(20,90,100)

# %%
my_total_inn_score_in_cricket
# Out:
# array([48, 82, 74, 77, 28, 42, 79, 59, 66, 70, 34, 51, 87, 39, 30, 81, 31,
#        87, 61, 87, 74, 86, 75, 64, 38, 22, 62, 25, 77, 32, 22, 32, 74, 21,
#        36, 83, 57, 23, 26, 59, 46, 55, 38, 64, 35, 72, 80, 34, 79, 36, 86,
#        60, 39, 21, 70, 59, 50, 37, 65, 31, 79, 56, 68, 58, 83, 63, 73, 73,
#        22, 36, 28, 20, 44, 29, 38, 63, 88, 67, 29, 44, 66, 56, 30, 40, 30,
#        80, 77, 73, 83, 63, 50, 56, 84, 77, 22, 81, 27, 59, 22, 58])

# %%
sample1=np.random.choice(my_total_inn_score_in_cricket,25)

# %%
sample2=np.random.choice(my_total_inn_score_in_cricket,25)

# %%
sample1
# Out:
# array([37, 64, 34, 31, 86, 73, 21, 59, 74, 72, 36, 79, 28, 81, 34, 42, 63,
#        61, 61, 58, 87, 28, 68, 56, 83])

# %%
sample1=[37, 64, 34, 31, 86, 3, 21, 5, 74, 7, 6, 79, 28, 1, 4, 2, 63,
       61, 61, 58, 87, 28, 68, 6, 8]

# %%
np.mean(sample1)
# Out:
# 36.88

# %%
sample2
# Out:
# array([63, 86, 63, 34, 23, 72, 35, 73, 23, 66, 63, 22, 84, 63, 79, 72, 21,
#        70, 83, 26, 79, 70, 36, 59, 83])

# %%
np.mean(sample1)
# Out:
# 56.64

# %%
np.mean(sample2)
# Out:
# 57.92

# %%
from scipy import stats
stats.ttest_rel(sample1,sample2)
# Out:
# Ttest_relResult(statistic=-2.3230789425166702, pvalue=0.028972315289055705)

# %%
sample1 != sample2
the meaning is if two sample mean from same population is not equal to each other we are going to reject the null hyphothesis

# %%
# chi-squre test

# %%
# Anova test(f-test)

# %%
sunday-chi-squre test,Anova test(f-test),EDA part-1 10 AM t0 1 PM ist
saturday and sunday EDA part-2 few techniques of feature eng

# %%
tuesday class
intro of ml and first ml algo

# %%
1,2,3
will start the project
4,5,6,7,9
then will comlete the project
clustering,pca,basic of DL
10,11,12
