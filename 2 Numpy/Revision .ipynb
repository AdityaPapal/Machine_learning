# %%
import numpy as np

# %%
data = np.random.randn(200)

# %%
data
# Out:
# array([ 1.48125401e+00, -9.51949512e-01, -2.11809965e+00,  7.65277786e-01,
#         8.33061440e-01, -1.19333321e+00, -5.51748717e-01,  2.87980904e-01,
#         3.06880093e-01,  2.42261928e+00,  6.18660525e-01,  6.24137571e-01,
#         2.00205201e+00, -1.39236230e-01,  3.32618969e+00, -1.21491777e+00,
#        -3.31194157e-01,  1.35315481e+00,  2.78967551e-01,  8.22896196e-01,
#        -1.38377656e-01,  1.67635306e+00,  1.46774885e+00, -6.44902746e-01,
#         3.92200517e-01,  2.04526017e-01,  2.00011396e+00, -2.12205671e+00,
#         4.18239783e-01, -2.19157716e+00,  2.32050292e+00, -1.59661115e+00,
#        -1.34362553e-01, -1.24990005e+00,  1.41049204e+00, -6.40688741e-01,
#         2.85961238e+00,  6.86497340e-01,  2.00456221e-01, -6.89628646e-01,
#         1.41689794e+00, -3.28803995e-01, -1.23217633e+00, -1.53045963e-01,
#         1.66726837e-01, -2.77458681e-01, -8.60993344e-01, -1.18520747e+00,
# ...

# %%
import seaborn as sns
sns.displot(data)

# %%
# 1. we can create a array np.array() np.asarray()
# 2. we can genrate a array with random number (rand,randn,ranint,arange,choice)
# 3. we can genrate some specific array like zeros ones full with any value or empty and empty like
